# %%
import os
import sounddevice as sd
import numpy as np
from faster_whisper import WhisperModel
import ollama
from IPython.display import clear_output
import time

# %%
model_size = "small"
model = WhisperModel(model_size, device="cuda")

# %%
#Fixed length recording audio
duration = 10.5  # seconds
fs = 16000
myrecording = sd.rec(int(duration * fs), samplerate=fs, channels=1)
sd.wait()
segments, info = model.transcribe(myrecording.flatten(), beam_size = 5)
for segment in segments:
    print("[%.2fs -> %.2fs] %s" % (segment.start, segment.end, segment.text))

# %%
#Play Audio
sd.play(myrecording, fs)

# %%
stream = sd.InputStream(samplerate = 16000, channels = 1, callback = audio_callback, blocksize=16000)

# %%
stream.stop()

# %%
#example_string = "wow this is a really long string thath as like, stuff going on in it, for example, text that I am writing here"



def text_output():
    #clear_output()

    global text_string
    global transcript_iter
    
    print("Transcript_iter - " + str(transcript_iter)) 
    print("----")
    print("text_string initially is: \n" + text_string)
    
    last_10_words = " ".join(text_string.split()[-10:])
    text_string = text_string[:-len(last_10_words)]

    print("----")
    print("last_10_words is: \n" + last_10_words)
    print("----")
    print("text_string with words removed: \n" + text_string)
    print("----")
    
    
    section_a = last_10_words
    section_b = whisper_out

    print("whisper_out is: \n" + whisper_out)
    print("----")
    llm_message = '''Here are the two transcript fragments
    1: ''' + section_a + '''
    2: ''' + section_b
    
    response = ollama.chat(model='llama3.1:8b', messages=[
        {'role': 'system', 'content': '''You merge overlapping transcript fragments. The end of transcript 1 overlaps with the start of transcript 2. Remove the duplication and return ONLY the merged text.
        
        Rules:
        - Output ONLY the merged text
        - No explanations, notes, or commentary
        - If there is no clear overlap, return transcript 2 unchanged
        
        Example:
        1: The cat sat on the mat
        2: on the mat and then fell asleep
        Output: The cat sat on the mat and then fell asleep'''}
        ,
        {'role': 'user', 'content': llm_message}
    ])
    
    text_string += " " + response['message']['content']
    transcript_iter += 1

    print("Updated text_string is: \n" + text_string)

# %%
text_string = ""
transcript_iter = 1

audio_chunks = []
def audio_callback(indata, frames, time, status):
    audio_chunks.append(indata.copy())

stream.start()
while True:
    if len(audio_chunks) >= 5:
        full_audio = np.concatenate(audio_chunks)
        del audio_chunks[0:3]
        segments, info = model.transcribe(full_audio.flatten(), beam_size = 5)
        whisper_out = ""
        for segment in segments:
            whisper_out += segment.text
        text_output()
    sd.sleep(100)
# Out:
# Transcript_iter - 1
# ----
# text_string initially is:
#
# ----
# last_10_words is:
#
# ----
# text_string with words removed:
#
# ----
# whisper_out is:
#  The strange symbols at the end are whispered.
# ----
# Updated text_string is:
#  The strange symbols at the end are whispered.
# Transcript_iter - 2
# ----
# text_string initially is:
#  The strange symbols at the end are whispered.
# ----
# last_10_words is:
# The strange symbols at the end are whispered.
# ----
# text_string with words removed:
#
# ----
# whisper_out is:
#  At the end, I'll whisper hallucinating during silence, a known quote.
# ----
# Updated text_string is:
#   The strange symbols at the end are whispered. At the end, I'll whisper hallucinating during silence, a known quote.
# Transcript_iter - 3
# ----
# text_string initially is:
#   The strange symbols at the end are whispered. At the end, I'll whisper hallucinating during silence, a known quote.
# ----
# last_10_words is:
# the end, I'll whisper hallucinating during silence, a known quote.
# ----
# text_string with words removed:
#   The strange symbols at the end are whispered. At
# ----
# whisper_out is:
#  silence, a known quirk. You'll likely want to handle that eventually.
# ----
# Updated text_string is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence, a known quote. You'll likely want to handle that eventually.
# Transcript_iter - 4
# ----
# text_string initially is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence, a known quote. You'll likely want to handle that eventually.
# ----
# last_10_words is:
# a known quote. You'll likely want to handle that eventually.
# ----
# text_string with words removed:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,
# ----
# whisper_out is:
#  likely want to handle that eventually, perhaps by filtering out chunks where whisper abut
# ----
# Updated text_string is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle that eventually, perhaps by filtering out chunks where whisper about
# Transcript_iter - 5
# ----
# text_string initially is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle that eventually, perhaps by filtering out chunks where whisper about
# ----
# last_10_words is:
# that eventually, perhaps by filtering out chunks where whisper about
# ----
# text_string with words removed:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle
# ----
# whisper_out is:
#  during your chunks, where Whisperer produces non-Latin characters or very low confidence scores.
# ----
# Updated text_string is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks where Whisper produces non-Latin characters or very low confidence scores.
# Transcript_iter - 6
# ----
# text_string initially is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks where Whisper produces non-Latin characters or very low confidence scores.
# ----
# last_10_words is:
# where Whisper produces non-Latin characters or very low confidence scores.
# ----
# text_string with words removed:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks
# ----
# whisper_out is:
#  characters, or very low confidence scores, or by implementing that V-
# ----
# Updated text_string is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters, or very low confidence scores, or by implementing that V
# Transcript_iter - 7
# ----
# text_string initially is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters, or very low confidence scores, or by implementing that V
# ----
# last_10_words is:
# or very low confidence scores, or by implementing that V
# ----
# text_string with words removed:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,
# ----
# whisper_out is:
#  or by implementing that VAD, Voice Activity Detection.
# ----
# Updated text_string is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low confidence scores, or by implementing that VAD, Voice Activity Detection.
# Transcript_iter - 8
# ----
# text_string initially is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low confidence scores, or by implementing that VAD, Voice Activity Detection.
# ----
# last_10_words is:
# confidence scores, or by implementing that VAD, Voice Activity Detection.
# ----
# text_string with words removed:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low
# ----
# whisper_out is:
#  voice activity detection, we discussed earlier to avoid transcribing silence.
# ----
# Updated text_string is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low  confidence scores, or by implementing that VAD, Voice Activity Detection.
# Transcript_iter - 9
# ----
# text_string initially is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low  confidence scores, or by implementing that VAD, Voice Activity Detection.
# ----
# last_10_words is:
# confidence scores, or by implementing that VAD, Voice Activity Detection.
# ----
# text_string with words removed:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low
# ----
# whisper_out is:
#  earlier to avoid transcribing silence altogether. Try a more naturalistic test.
# ----
# Updated text_string is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low   confidence scores, or by implementing that VAD, Voice Activity Detection. earlier to avoid transcribing silence altogether. Try a more naturalistic test.
# Transcript_iter - 10
# ----
# text_string initially is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low   confidence scores, or by implementing that VAD, Voice Activity Detection. earlier to avoid transcribing silence altogether. Try a more naturalistic test.
# ----
# last_10_words is:
# to avoid transcribing silence altogether. Try a more naturalistic test.
# ----
# text_string with words removed:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low   confidence scores, or by implementing that VAD, Voice Activity Detection. earlier
# ----
# whisper_out is:
#  Try a more naturalistic test. Speak a few senses as you would normally.
# ----
# Updated text_string is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low   confidence scores, or by implementing that VAD, Voice Activity Detection. earlier  to avoid transcribing silence altogether. Speak a few sentences as you would normally.
# Transcript_iter - 11
# ----
# text_string initially is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low   confidence scores, or by implementing that VAD, Voice Activity Detection. earlier  to avoid transcribing silence altogether. Speak a few sentences as you would normally.
# ----
# last_10_words is:
# silence altogether. Speak a few sentences as you would normally.
# ----
# text_string with words removed:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low   confidence scores, or by implementing that VAD, Voice Activity Detection. earlier  to avoid transcribing
# ----
# whisper_out is:
#  sensors as you would normally. I suspect you'll see considerably cleaner results since with
# ----
# Updated text_string is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low   confidence scores, or by implementing that VAD, Voice Activity Detection. earlier  to avoid transcribing  silence altogether. Speak a few sentences as you would normally. I suspect you'll see considerably cleaner results since
# Transcript_iter - 12
# ----
# text_string initially is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low   confidence scores, or by implementing that VAD, Voice Activity Detection. earlier  to avoid transcribing  silence altogether. Speak a few sentences as you would normally. I suspect you'll see considerably cleaner results since
# ----
# last_10_words is:
# would normally. I suspect you'll see considerably cleaner results since
# ----
# text_string with words removed:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low   confidence scores, or by implementing that VAD, Voice Activity Detection. earlier  to avoid transcribing  silence altogether. Speak a few sentences as you
# ----
# whisper_out is:
#  considerably cleaner results since whisper and the LLM will have actual linguistic context.
# ----
# Updated text_string is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low   confidence scores, or by implementing that VAD, Voice Activity Detection. earlier  to avoid transcribing  silence altogether. Speak a few sentences as you  would normally. I suspect you'll see considerably cleaner results since whisper and the LLM will have actual linguistic context.
# Transcript_iter - 13
# ----
# text_string initially is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low   confidence scores, or by implementing that VAD, Voice Activity Detection. earlier  to avoid transcribing  silence altogether. Speak a few sentences as you  would normally. I suspect you'll see considerably cleaner results since whisper and the LLM will have actual linguistic context.
# ----
# last_10_words is:
# since whisper and the LLM will have actual linguistic context.
# ----
# text_string with words removed:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low   confidence scores, or by implementing that VAD, Voice Activity Detection. earlier  to avoid transcribing  silence altogether. Speak a few sentences as you  would normally. I suspect you'll see considerably cleaner results
# ----
# whisper_out is:
#  we'll have actual linguistic context to work with rather than isolated letters.
# ----
# Updated text_string is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low   confidence scores, or by implementing that VAD, Voice Activity Detection. earlier  to avoid transcribing  silence altogether. Speak a few sentences as you  would normally. I suspect you'll see considerably cleaner results  since whisper and the LLM will have actual linguistic context to work with rather than isolated letters.
# Transcript_iter - 14
# ----
# text_string initially is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low   confidence scores, or by implementing that VAD, Voice Activity Detection. earlier  to avoid transcribing  silence altogether. Speak a few sentences as you  would normally. I suspect you'll see considerably cleaner results  since whisper and the LLM will have actual linguistic context to work with rather than isolated letters.
# ----
# last_10_words is:
# actual linguistic context to work with rather than isolated letters.
# ----
# text_string with words removed:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low   confidence scores, or by implementing that VAD, Voice Activity Detection. earlier  to avoid transcribing  silence altogether. Speak a few sentences as you  would normally. I suspect you'll see considerably cleaner results  since whisper and the LLM will have
# ----
# whisper_out is:
#  than isolated letters.
# ----
# Updated text_string is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low   confidence scores, or by implementing that VAD, Voice Activity Detection. earlier  to avoid transcribing  silence altogether. Speak a few sentences as you  would normally. I suspect you'll see considerably cleaner results  since whisper and the LLM will have  actual linguistic context to work with rather than isolated letters.
# Transcript_iter - 15
# ----
# text_string initially is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low   confidence scores, or by implementing that VAD, Voice Activity Detection. earlier  to avoid transcribing  silence altogether. Speak a few sentences as you  would normally. I suspect you'll see considerably cleaner results  since whisper and the LLM will have  actual linguistic context to work with rather than isolated letters.
# ----
# last_10_words is:
# actual linguistic context to work with rather than isolated letters.
# ----
# text_string with words removed:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low   confidence scores, or by implementing that VAD, Voice Activity Detection. earlier  to avoid transcribing  silence altogether. Speak a few sentences as you  would normally. I suspect you'll see considerably cleaner results  since whisper and the LLM will have
# ----
# whisper_out is:
#
# ----
# Updated text_string is:
#   The strange symbols at the end are whispered. At  the end, I'll whisper hallucinating during silence,  The merged text is:
# likely want to handle  that eventually, perhaps by filtering out chunks  where Whisper produces non-Latin characters,  or very low   confidence scores, or by implementing that VAD, Voice Activity Detection. earlier  to avoid transcribing  silence altogether. Speak a few sentences as you  would normally. I suspect you'll see considerably cleaner results  since whisper and the LLM will have   actual linguistic context to work with rather than isolated letters.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[71], line 15
#      13 segments, info = model.transcribe(full_audio.flatten(), beam_size = 5)
#      14 whisper_out = ""
# ---> 15 for segment in segments:
#      16     whisper_out += segment.text
#      17 text_output()
#
# File C:\whisper-streaming\Lib\site-packages\faster_whisper\transcribe.py:1213, in WhisperModel.generate_segments(self, features, tokenizer, options, log_progress, encoder_output)
#    1198     tokenizer.language_code = language
#    1200 prompt = self.get_prompt(
#    1201     tokenizer,
#    1202     previous_tokens,
#    (...)   1205     hotwords=options.hotwords,
#    1206 )
#    1208 (
#    1209     result,
#    1210     avg_logprob,
#    1211     temperature,
#    1212     compression_ratio,
# -> 1213 ) = self.generate_with_fallback(encoder_output, prompt, tokenizer, options)
#    1215 if options.no_speech_threshold is not None:
#    1216     # no voice activity check
#    1217     should_skip = result.no_speech_prob > options.no_speech_threshold
#
# File C:\whisper-streaming\Lib\site-packages\faster_whisper\transcribe.py:1446, in WhisperModel.generate_with_fallback(self, encoder_output, prompt, tokenizer, options)
#    1440 else:
#    1441     kwargs = {
#    1442         "beam_size": options.beam_size,
#    1443         "patience": options.patience,
#    1444     }
# -> 1446 result = self.model.generate(
#    1447     encoder_output,
#    1448     [prompt],
#    1449     length_penalty=options.length_penalty,
#    1450     repetition_penalty=options.repetition_penalty,
#    1451     no_repeat_ngram_size=options.no_repeat_ngram_size,
#    1452     max_length=max_length,
#    1453     return_scores=True,
#    1454     return_no_speech_prob=True,
#    1455     suppress_blank=options.suppress_blank,
#    1456     suppress_tokens=options.suppress_tokens,
#    1457     max_initial_timestamp_index=max_initial_timestamp_index,
#    1458     **kwargs,
#    1459 )[0]
#    1461 tokens = result.sequences_ids[0]
#    1463 # Recover the average log prob from the returned score.
#
# KeyboardInterrupt:

# %%
text_string
# Out:
# 'One, two, three, four, fiveone, two, three, four, five, six, seven, eightthree, four, five, six, seven, eight, nine, ten, eleven, twelveeightthree, four, five, six, seven, eight, nine, ten, eleven, twelve, 13, 14, 15, 1614, 15, 16, 17, 18, 1919, 20, 21, 2215, 1614, 15, 16, 17, 18, 1919, 20, 21, 22, 23, 24, 25, 2624, 25, 26, 27, 28, 29280, 31, 323123, 2624, 34, 353420, 36, 37, 38, 323123The cat sat on the mat and then fell asleep320The cat sat on the mat and then fell asleep'

# %%
#let's play around and remember how functions work
thevar = 4

def outer_func():

    def inner_func():
        globals()["thevar"] += 1
    inner_func()

outer_func()
print(thevar)
# Out:
# 5

# %%
response = ollama.chat(model='llama3.1:8b', messages=[
{'role': 'system', 'content': '''You merge overlapping transcript fragments into clean text. The end of transcript 1 overlaps with the start of transcript 2 - they contain the same spoken words. Remove the duplication.
Return only the merged result, nothing else.
Example:
1: The cat sat on the mat
2: on the mat and then fell asleep
Result: The cat sat on the mat and then fell asleep'''}
    ,
    {'role': 'user', 'content': '''Merge these overlapping transcripts:
1: This is going to record the audio in 5 second chunks.
2: in five-second chunks and then it is going to be deleting'''}
])



print(response['message']['content'])
# Out:
# Here's the merged result:
#
# This is going to record the audio in 5-second chunks and then it is going to be deleting.

# %%
while True:
    clear_output()
    print(np.random.random_sample())
    time.sleep(.5)
# Out:
# 0.6683588557830332
# 0.4148140914551536
# 0.26635671555575136
# 0.7964962444358041
# 0.7793093868708993
# 0.5665282894116243
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 while True:
#       2     #clear_output()
#       3     print(np.random.random_sample())
# ----> 4     time.sleep(.5)
#
# KeyboardInterrupt:
